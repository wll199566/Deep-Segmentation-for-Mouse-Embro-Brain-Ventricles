# %%
import os
import numpy as np
from scipy import ndimage
from skimage import io
from matplotlib import pyplot as plt
import pickle
import nibabel as nib
from scipy.ndimage.interpolation import zoom
import random

# %%
def pickle_store(file_name,save_data):
    fileObj = open(file_name,'wb')
    pickle.dump(save_data,fileObj)
    fileObj.close()

def extract_positive(whole_img,whole_label,box_size,smallest_ratio=0.97,step_size=7,verbal=False):
    img_size=np.shape(whole_img)
    bv_voxel_num=np.sum(whole_label)
    positive_sub_volumes=[]
    x_slice,y_slice,z_slice = ndimage.find_objects(whole_label)[0]
    offset=9
    
    x_start = x_slice.stop-offset if x_slice.stop-offset >= box_size else box_size
    x_stop = x_slice.start+box_size+offset if x_slice.start+box_size+offset <= img_size[0] else img_size[0]
    
    y_start = y_slice.stop-offset if y_slice.stop-offset >= box_size else box_size
    y_stop = y_slice.start+box_size+offset if y_slice.start+box_size+offset <= img_size[1] else img_size[1]
    
    z_start = z_slice.stop-offset if z_slice.stop-offset >= box_size else box_size
    z_stop = z_slice.start+box_size+offset if z_slice.start+box_size+offset <= img_size[2] else img_size[2]
    
    for i in range(x_start,x_stop+1,step_size):
        for j in range(y_start,y_stop+1,step_size):
            for k in range(z_start,z_stop+1,step_size):
                contain_ratio = np.sum(whole_label[i-box_size:i,
                                                   j-box_size:j,
                                                   k-box_size:k])/(bv_voxel_num+0.001)
                if verbal==True:
                    print('Current box contain bv ratio: ',contain_ratio)
                if contain_ratio > smallest_ratio:
                    positive_sub_volumes.append((i,j,k))
    return positive_sub_volumes

# %%
file_path = os.path.join('/scratch/zq415/grammar_cor/Localization/data','2018_0711_train_sub_volumes22.pickle')
with open(file_path,'rb') as f:
    #(neg_subvolumes,pos_subvolumes,img2,filtered_img2, img_label2, 
    # img, filtered_img, img_label, data_dic[i][0])
    all_data = pickle.load(f)
f.close()
HALF_SIDE = 128

# %%
all_sub_volumes={}
total_pos=0
all_name = {}

for i in range(len(all_data)):
    img = all_data[i][5]
    filtered_img = all_data[i][6]
    img_label = all_data[i][7]
    all_name[i] = all_data[i][8]
    print("Number {0}: img_size: {1}, bv_size: {2}, bv_volume: {3}".format(i,
                                                                           np.shape(img),
                                                                           ndimage.find_objects(img_label)[0],
                                                                           np.sum(img_label)))
    
    print("Extracting positive: ...")
    pos_subvolumes=extract_positive(img,img_label,HALF_SIDE)
    current_pos_num=len(pos_subvolumes)
    if current_pos_num>700:
        pos_subvolumes=extract_positive(img,img_label,HALF_SIDE,smallest_ratio=0.98,step_size=9)
        current_pos_num=len(pos_subvolumes)

    if current_pos_num<100:
        pos_subvolumes=extract_positive(img,img_label,HALF_SIDE,smallest_ratio=0.96,step_size=4)
        current_pos_num=len(pos_subvolumes)
    total_pos+=current_pos_num
    
    print("{}:, pos_len={} \n".format(all_name[i],current_pos_num))
    
    all_sub_volumes[i]=(pos_subvolumes,img,filtered_img,img_label,all_name[i])


pickle_store('./data/2018_0711_train_sub_volumes22_seg.pickle',all_sub_volumes)
print(total_pos)
# Out:
# Number 0: img_size: (210, 242, 242), bv_size: (slice(87, 153, None), slice(38, 132, None), slice(18, 83, None)), bv_volume: 30640
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E2aMut_ext.nii:, pos_len=243
#
# Number 1: img_size: (210, 242, 262), bv_size: (slice(82, 166, None), slice(102, 176, None), slice(17, 74, None)), bv_volume: 16795
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E8a.nii:, pos_len=207
#
# Number 2: img_size: (210, 242, 262), bv_size: (slice(56, 119, None), slice(77, 187, None), slice(18, 75, None)), bv_volume: 21659
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E11a.nii:, pos_len=180
#
# Number 3: img_size: (210, 242, 222), bv_size: (slice(85, 161, None), slice(122, 194, None), slice(10, 81, None)), bv_volume: 24917
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E6a.nii:, pos_len=128
#
# Number 4: img_size: (210, 242, 242), bv_size: (slice(70, 139, None), slice(106, 191, None), slice(21, 89, None)), bv_volume: 17125
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E7a.nii:, pos_len=348
#
# Number 5: img_size: (180, 242, 182), bv_size: (slice(58, 112, None), slice(51, 148, None), slice(79, 152, None)), bv_volume: 24896
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E1a.nii:, pos_len=240
#
# Number 6: img_size: (210, 242, 242), bv_size: (slice(80, 160, None), slice(46, 142, None), slice(12, 57, None)), bv_volume: 24567
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E3a_Res_Ext.nii:, pos_len=168
#
# Number 7: img_size: (210, 242, 242), bv_size: (slice(51, 150, None), slice(22, 71, None), slice(170, 215, None)), bv_volume: 14406
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E5a_Mut_Ext.nii:, pos_len=136
#
# Number 8: img_size: (210, 242, 242), bv_size: (slice(79, 157, None), slice(47, 144, None), slice(11, 58, None)), bv_volume: 24334
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E4a_Res_Ext.nii:, pos_len=152
#
# Number 9: img_size: (210, 242, 262), bv_size: (slice(57, 120, None), slice(92, 205, None), slice(152, 215, None)), bv_volume: 22980
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E10a.nii:, pos_len=360
#
# Number 10: img_size: (210, 242, 242), bv_size: (slice(95, 142, None), slice(89, 194, None), slice(12, 62, None)), bv_volume: 17168
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20171211_En1_E13p5__upload/20171211_En1_E13_E9a.nii:, pos_len=165
#
# Number 11: img_size: (180, 282, 242), bv_size: (slice(66, 138, None), slice(10, 80, None), slice(105, 230, None)), bv_volume: 26871
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E1a.nii:, pos_len=364
#
# Number 12: img_size: (180, 282, 182), bv_size: (slice(44, 108, None), slice(152, 244, None), slice(11, 80, None)), bv_volume: 29817
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E6b.nii:, pos_len=126
#
# Number 13: img_size: (180, 282, 162), bv_size: (slice(26, 99, None), slice(147, 227, None), slice(17, 113, None)), bv_volume: 31864
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E7a.nii:, pos_len=163
#
# Number 14: img_size: (180, 282, 182), bv_size: (slice(33, 94, None), slice(142, 240, None), slice(25, 110, None)), bv_volume: 29709
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E5a.nii:, pos_len=180
#
# Number 15: img_size: (180, 282, 182), bv_size: (slice(59, 121, None), slice(86, 193, None), slice(114, 164, None)), bv_volume: 20507
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E3a.nii:, pos_len=120
#
# Number 16: img_size: (180, 282, 182), bv_size: (slice(28, 102, None), slice(136, 218, None), slice(22, 77, None)), bv_volume: 19845
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E8a.nii:, pos_len=160
#
# Number 17: img_size: (180, 282, 202), bv_size: (slice(51, 137, None), slice(195, 252, None), slice(107, 195, None)), bv_volume: 31645
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E2a.nii:, pos_len=599
#
# Number 18: img_size: (180, 282, 202), bv_size: (slice(42, 130, None), slice(106, 171, None), slice(110, 196, None)), bv_volume: 31598
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13.5/20170330_En1_E13p5-files__upload/20170330_En1_E13_E4a.nii:, pos_len=154
#
# Number 19: img_size: (180, 202, 162), bv_size: (slice(36, 98, None), slice(40, 108, None), slice(10, 68, None)), bv_volume: 22574
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E5a.nii:, pos_len=126
#
# Number 20: img_size: (180, 202, 202), bv_size: (slice(44, 100, None), slice(32, 103, None), slice(76, 173, None)), bv_volume: 32966
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E6a.nii:, pos_len=252
#
# Number 21: img_size: (180, 202, 182), bv_size: (slice(46, 119, None), slice(38, 97, None), slice(40, 115, None)), bv_volume: 32997
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E7a.nii:, pos_len=391
#
# Number 22: img_size: (180, 202, 162), bv_size: (slice(51, 127, None), slice(11, 59, None), slice(28, 72, None)), bv_volume: 26258
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E2a.nii:, pos_len=120
#
# Number 23: img_size: (180, 222, 162), bv_size: (slice(44, 123, None), slice(74, 122, None), slice(36, 88, None)), bv_volume: 21071
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E1a.nii:, pos_len=420
#
# Number 24: img_size: (180, 202, 162), bv_size: (slice(41, 100, None), slice(25, 68, None), slice(58, 141, None)), bv_volume: 25185
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E4a.nii:, pos_len=140
#
# Number 25: img_size: (180, 202, 182), bv_size: (slice(40, 122, None), slice(55, 99, None), slice(15, 78, None)), bv_volume: 25716
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20171002_En1_E11p5-files__upload/20171002_En1_E11_E3a.nii:, pos_len=189
#
# Number 26: img_size: (180, 202, 182), bv_size: (slice(49, 113, None), slice(74, 150, None), slice(111, 172, None)), bv_volume: 29748
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E5a.nii:, pos_len=128
#
# Number 27: img_size: (180, 202, 142), bv_size: (slice(73, 148, None), slice(110, 162, None), slice(43, 89, None)), bv_volume: 23739
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E1a.nii:, pos_len=126
#
# Number 28: img_size: (180, 202, 162), bv_size: (slice(42, 124, None), slice(89, 148, None), slice(72, 142, None)), bv_volume: 48829
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E6a.nii:, pos_len=252
#
# Number 29: img_size: (180, 202, 162), bv_size: (slice(65, 121, None), slice(90, 162, None), slice(17, 80, None)), bv_volume: 28962
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E3a.nii:, pos_len=224
#
# Number 30: img_size: (180, 202, 142), bv_size: (slice(43, 92, None), slice(82, 151, None), slice(34, 105, None)), bv_volume: 27461
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E2b.nii:, pos_len=168
#
# Number 31: img_size: (180, 202, 162), bv_size: (slice(52, 133, None), slice(69, 124, None), slice(76, 150, None)), bv_volume: 34176
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170314_En1_E11p5-files__upload/20170314_En1_E11_E4b.nii:, pos_len=253
#
# Number 32: img_size: (180, 202, 128), bv_size: (slice(48, 96, None), slice(86, 161, None), slice(45, 105, None)), bv_volume: 23721
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E1b.nii:, pos_len=167
#
# Number 33: img_size: (180, 202, 182), bv_size: (slice(34, 102, None), slice(44, 109, None), slice(108, 179, None)), bv_volume: 33169
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E7a.nii:, pos_len=380
#
# Number 34: img_size: (180, 202, 128), bv_size: (slice(62, 148, None), slice(116, 188, None), slice(53, 103, None)), bv_volume: 29267
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E2a.nii:, pos_len=66
#
# Number 35: img_size: (180, 202, 128), bv_size: (slice(47, 113, None), slice(36, 101, None), slice(71, 114, None)), bv_volume: 20006
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E4a.nii:, pos_len=143
#
# Number 36: img_size: (180, 202, 172), bv_size: (slice(32, 107, None), slice(20, 95, None), slice(14, 69, None)), bv_volume: 27421
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E5a.nii:, pos_len=385
#
# Number 37: img_size: (180, 202, 128), bv_size: (slice(54, 130, None), slice(106, 168, None), slice(39, 85, None)), bv_volume: 20758
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170328_En1_E11p5-files__upload/20170328_En1_E11_E3a.nii:, pos_len=140
#
# Number 38: img_size: (180, 222, 142), bv_size: (slice(81, 135, None), slice(37, 109, None), slice(41, 120, None)), bv_volume: 32801
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170320_En1_E11p5-files__upload/20170320_En1_E11_E1a.nii:, pos_len=147
#
# Number 39: img_size: (180, 222, 128), bv_size: (slice(43, 114, None), slice(81, 151, None), slice(49, 98, None)), bv_volume: 28062
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170320_En1_E11p5-files__upload/20170320_En1_E11_E2a.nii:, pos_len=216
#
# Number 40: img_size: (180, 222, 182), bv_size: (slice(40, 96, None), slice(36, 121, None), slice(109, 176, None)), bv_volume: 29485
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170320_En1_E11p5-files__upload/20170320_En1_E11_E3b.nii:, pos_len=420
#
# Number 41: img_size: (180, 222, 142), bv_size: (slice(53, 110, None), slice(80, 159, None), slice(13, 53, None)), bv_volume: 22110
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11/20170320_En1_E11p5-files__upload/20170320_En1_E11_E6a.nii:, pos_len=232
#
# Number 42: img_size: (180, 282, 142), bv_size: (slice(40, 108, None), slice(106, 211, None), slice(28, 87, None)), bv_volume: 24912
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E6a.nii:, pos_len=144
#
# Number 43: img_size: (180, 282, 128), bv_size: (slice(81, 136, None), slice(94, 198, None), slice(42, 85, None)), bv_volume: 11660
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E3b.nii:, pos_len=130
#
# Number 44: img_size: (180, 282, 202), bv_size: (slice(53, 113, None), slice(12, 76, None), slice(49, 174, None)), bv_volume: 22418
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E4a_reg.nii:, pos_len=420
#
# Number 45: img_size: (180, 282, 142), bv_size: (slice(70, 136, None), slice(185, 253, None), slice(19, 103, None)), bv_volume: 21003
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E5a.nii:, pos_len=105
#
# Number 46: img_size: (180, 282, 182), bv_size: (slice(65, 121, None), slice(144, 238, None), slice(21, 80, None)), bv_volume: 13410
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E2a.nii:, pos_len=224
#
# Number 47: img_size: (180, 282, 212), bv_size: (slice(65, 115, None), slice(11, 63, None), slice(47, 162, None)), bv_volume: 19356
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14.5/20170331_En1_E14p5-files__upload/20170331_En1_E14p_E4b.nii:, pos_len=448
#
# Number 48: img_size: (180, 202, 128), bv_size: (slice(79, 114, None), slice(121, 164, None), slice(68, 102, None)), bv_volume: 6197
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171211_En1_E10p5-files__upload/20171211_En1_E10_E4b.nii:, pos_len=154
#
# Number 49: img_size: (180, 202, 142), bv_size: (slice(70, 123, None), slice(82, 138, None), slice(59, 95, None)), bv_volume: 11985
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171211_En1_E10p5-files__upload/20171211_En1_E10_E1a.nii:, pos_len=240
#
# Number 50: img_size: (180, 202, 182), bv_size: (slice(80, 117, None), slice(99, 168, None), slice(93, 150, None)), bv_volume: 19831
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E1b.nii:, pos_len=240
#
# Number 51: img_size: (180, 242, 162), bv_size: (slice(61, 109, None), slice(47, 103, None), slice(11, 93, None)), bv_volume: 26566
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E3a.nii:, pos_len=192
#
# Number 52: img_size: (180, 202, 182), bv_size: (slice(82, 119, None), slice(92, 165, None), slice(58, 104, None)), bv_volume: 19079
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E1a.nii:, pos_len=384
#
# Number 53: img_size: (180, 242, 162), bv_size: (slice(56, 107, None), slice(43, 113, None), slice(22, 107, None)), bv_volume: 29903
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E5a.nii:, pos_len=280
#
# Number 54: img_size: (180, 242, 162), bv_size: (slice(85, 122, None), slice(45, 112, None), slice(41, 108, None)), bv_volume: 20212
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E4a.nii:, pos_len=320
#
# Number 55: img_size: (180, 242, 162), bv_size: (slice(77, 113, None), slice(56, 127, None), slice(5, 60, None)), bv_volume: 16477
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20171208_En1_E10p5-files__upload/20171208_En1_E10_E2a.nii:, pos_len=144
#
# Number 56: img_size: (150, 162, 128), bv_size: (slice(18, 85, None), slice(91, 134, None), slice(32, 82, None)), bv_volume: 19031
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E4a_reg_filt.nii:, pos_len=53
#
# Number 57: img_size: (150, 162, 128), bv_size: (slice(32, 66, None), slice(68, 148, None), slice(63, 120, None)), bv_volume: 17792
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E3b_reg_filt.nii:, pos_len=30
#
# Number 58: img_size: (150, 162, 128), bv_size: (slice(35, 81, None), slice(39, 93, None), slice(51, 114, None)), bv_volume: 15013
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E5b_reg_filt.nii:, pos_len=54
#
# Number 59: img_size: (150, 162, 128), bv_size: (slice(17, 85, None), slice(109, 157, None), slice(25, 75, None)), bv_volume: 20413
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E4b_reg_filt.nii:, pos_len=23
#
# Number 60: img_size: (150, 162, 142), bv_size: (slice(54, 83, None), slice(77, 153, None), slice(62, 103, None)), bv_volume: 11826
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E1b_reg_filt.nii:, pos_len=96
#
# Number 61: img_size: (150, 162, 128), bv_size: (slice(45, 81, None), slice(69, 134, None), slice(42, 111, None)), bv_volume: 15232
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E2c_reg_filt.nii:, pos_len=48
#
# Number 62: img_size: (150, 162, 140), bv_size: (slice(55, 104, None), slice(51, 131, None), slice(62, 121, None)), bv_volume: 18360
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E2a_reg_filt.nii:, pos_len=216
#
# Number 63: img_size: (150, 162, 128), bv_size: (slice(28, 71, None), slice(62, 133, None), slice(62, 123, None)), bv_volume: 19423
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E3a_reg_filt.nii:, pos_len=54
#
# Number 64: img_size: (150, 162, 128), bv_size: (slice(43, 94, None), slice(52, 109, None), slice(38, 115, None)), bv_volume: 18804
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E5a_reg_filt.nii:, pos_len=54
#
# Number 65: img_size: (150, 162, 142), bv_size: (slice(56, 84, None), slice(84, 156, None), slice(67, 114, None)), bv_volume: 14053
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170313_En1_E10p5-files__upload/20170313_EN1_E10_E1a_reg_filt.nii:, pos_len=72
#
# Number 66: img_size: (180, 202, 128), bv_size: (slice(53, 106, None), slice(74, 121, None), slice(48, 115, None)), bv_volume: 15140
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170327_En1_E10p5-files_upload/20170327_En1_E10_E3a.nii:, pos_len=266
#
# Number 67: img_size: (180, 202, 128), bv_size: (slice(52, 100, None), slice(127, 181, None), slice(35, 106, None)), bv_volume: 17783
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170327_En1_E10p5-files_upload/20170327_En1_E10_E2a.nii:, pos_len=98
#
# Number 68: img_size: (180, 202, 142), bv_size: (slice(59, 135, None), slice(89, 150, None), slice(50, 108, None)), bv_volume: 26949
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170327_En1_E10p5-files_upload/20170327_En1_E10_E5a.nii:, pos_len=192
#
# Number 69: img_size: (180, 202, 128), bv_size: (slice(57, 107, None), slice(55, 142, None), slice(24, 112, None)), bv_volume: 45577
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E10/20170327_En1_E10p5-files_upload/20170327_En1_E10_E4a.nii:, pos_len=210
#
# Number 70: img_size: (180, 282, 252), bv_size: (slice(78, 137, None), slice(138, 234, None), slice(145, 225, None)), bv_volume: 19098
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E4a.nii:, pos_len=245
#
# Number 71: img_size: (180, 262, 282), bv_size: (slice(30, 97, None), slice(105, 190, None), slice(28, 86, None)), bv_volume: 23256
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E1a.nii:, pos_len=200
#
# Number 72: img_size: (180, 282, 282), bv_size: (slice(49, 106, None), slice(172, 232, None), slice(88, 185, None)), bv_volume: 19519
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E2a.nii:, pos_len=384
#
# Number 73: img_size: (180, 282, 222), bv_size: (slice(49, 103, None), slice(32, 101, None), slice(43, 140, None)), bv_volume: 23332
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E3a.nii:, pos_len=288
#
# Number 74: img_size: (180, 282, 282), bv_size: (slice(48, 104, None), slice(162, 227, None), slice(97, 194, None)), bv_volume: 19213
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E2b.nii:, pos_len=432
#
# Number 75: img_size: (180, 282, 222), bv_size: (slice(50, 102, None), slice(31, 101, None), slice(45, 141, None)), bv_volume: 19623
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E3b.nii:, pos_len=240
#
# Number 76: img_size: (180, 282, 242), bv_size: (slice(50, 129, None), slice(82, 155, None), slice(12, 61, None)), bv_volume: 17499
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E5b.nii:, pos_len=216
#
# Number 77: img_size: (180, 282, 252), bv_size: (slice(82, 138, None), slice(133, 227, None), slice(146, 228, None)), bv_volume: 23075
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E4b.nii:, pos_len=196
#
# Number 78: img_size: (180, 262, 282), bv_size: (slice(30, 100, None), slice(107, 193, None), slice(31, 92, None)), bv_volume: 22924
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170317_En1_E14p5-files__upload/20170317_En1_E14_E1b.nii:, pos_len=200
#
# Number 79: img_size: (180, 282, 222), bv_size: (slice(56, 111, None), slice(106, 213, None), slice(19, 66, None)), bv_volume: 15154
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170323_En1_E14p5-files__upload/20170323_En1_E14_E5a.nii:, pos_len=160
#
# Number 80: img_size: (180, 282, 242), bv_size: (slice(50, 144, None), slice(203, 252, None), slice(107, 171, None)), bv_volume: 14642
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170323_En1_E14p5-files__upload/20170323_En1_E14_E6a.nii:, pos_len=320
#
# Number 81: img_size: (180, 242, 242), bv_size: (slice(59, 157, None), slice(154, 212, None), slice(153, 226, None)), bv_volume: 18361
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170323_En1_E14p5-files__upload/20170323_En1_E14_E1a.nii:, pos_len=432
#
# Number 82: img_size: (180, 242, 242), bv_size: (slice(35, 122, None), slice(90, 155, None), slice(28, 86, None)), bv_volume: 17237
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170323_En1_E14p5-files__upload/20170323_En1_E14_E2a.nii:, pos_len=300
#
# Number 83: img_size: (180, 282, 262), bv_size: (slice(34, 95, None), slice(64, 136, None), slice(128, 209, None)), bv_volume: 21580
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E14/20170323_En1_E14p5-files__upload/20170323_En1_E14_E3a.nii:, pos_len=479
#
# Number 84: img_size: (180, 202, 142), bv_size: (slice(79, 139, None), slice(43, 108, None), slice(1, 57, None)), bv_volume: 22967
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E7a.nii:, pos_len=286
#
# Number 85: img_size: (180, 202, 142), bv_size: (slice(61, 136, None), slice(41, 73, None), slice(60, 119, None)), bv_volume: 19515
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E5a.nii:, pos_len=168
#
# Number 86: img_size: (180, 202, 142), bv_size: (slice(36, 104, None), slice(106, 140, None), slice(23, 95, None)), bv_volume: 22447
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E13a.nii:, pos_len=180
#
# Number 87: img_size: (180, 202, 182), bv_size: (slice(51, 131, None), slice(58, 98, None), slice(19, 69, None)), bv_volume: 25693
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E3a.nii:, pos_len=288
#
# Number 88: img_size: (180, 202, 162), bv_size: (slice(51, 128, None), slice(50, 86, None), slice(62, 118, None)), bv_volume: 20576
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E4b.nii:, pos_len=320
#
# Number 89: img_size: (180, 202, 162), bv_size: (slice(55, 134, None), slice(46, 96, None), slice(57, 124, None)), bv_volume: 25024
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E1a.nii:, pos_len=320
#
# Number 90: img_size: (180, 202, 128), bv_size: (slice(78, 141, None), slice(107, 150, None), slice(10, 80, None)), bv_volume: 19245
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E10a.nii:, pos_len=165
#
# Number 91: img_size: (180, 202, 142), bv_size: (slice(76, 147, None), slice(96, 155, None), slice(68, 128, None)), bv_volume: 22671
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E11a.nii:, pos_len=144
#
# Number 92: img_size: (180, 202, 162), bv_size: (slice(60, 135, None), slice(43, 99, None), slice(10, 69, None)), bv_volume: 25122
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E2a.nii:, pos_len=161
#
# Number 93: img_size: (180, 202, 128), bv_size: (slice(84, 128, None), slice(48, 113, None), slice(57, 119, None)), bv_volume: 19256
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E6a.nii:, pos_len=196
#
# Number 94: img_size: (180, 202, 162), bv_size: (slice(57, 124, None), slice(79, 143, None), slice(91, 149, None)), bv_volume: 24088
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E11.5/20171212_En1_E11p5-files__upload/20171212_En1_E11_E8a.nii:, pos_len=216
#
# Number 95: img_size: (180, 222, 222), bv_size: (slice(40, 133, None), slice(44, 107, None), slice(17, 74, None)), bv_volume: 25287
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171003_En1_E12p5-files__upload/20171003_En1_E12_E4a_Mut.nii:, pos_len=224
#
# Number 96: img_size: (180, 222, 202), bv_size: (slice(70, 143, None), slice(116, 176, None), slice(98, 181, None)), bv_volume: 31378
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171003_En1_E12p5-files__upload/20171003_En1_E12_E1a.nii:, pos_len=168
#
# Number 97: img_size: (180, 222, 242), bv_size: (slice(52, 139, None), slice(82, 147, None), slice(52, 108, None)), bv_volume: 8760
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171003_En1_E12p5-files__upload/20171003_En1_E12_E2c.nii:, pos_len=693
#
# Number 98: img_size: (180, 242, 162), bv_size: (slice(19, 92, None), slice(52, 115, None), slice(37, 114, None)), bv_volume: 27784
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E3a_reg.nii:, pos_len=180
#
# Number 99: img_size: (180, 242, 142), bv_size: (slice(60, 127, None), slice(47, 138, None), slice(24, 73, None)), bv_volume: 28175
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E12a_reg.nii:, pos_len=192
#
# Number 100: img_size: (180, 242, 142), bv_size: (slice(95, 146, None), slice(72, 163, None), slice(58, 124, None)), bv_volume: 30638
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E1a_reg.nii:, pos_len=126
#
# Number 101: img_size: (180, 242, 162), bv_size: (slice(64, 146, None), slice(77, 154, None), slice(90, 138, None)), bv_volume: 22947
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E7a_reg.nii:, pos_len=216
#
# Number 102: img_size: (180, 242, 162), bv_size: (slice(98, 162, None), slice(76, 125, None), slice(29, 111, None)), bv_volume: 24384
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E6a_reg.nii:, pos_len=180
#
# Number 103: img_size: (180, 242, 142), bv_size: (slice(20, 82, None), slice(58, 132, None), slice(15, 94, None)), bv_volume: 34129
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E13a_reg.nii:, pos_len=120
#
# Number 104: img_size: (180, 242, 162), bv_size: (slice(47, 107, None), slice(33, 122, None), slice(33, 94, None)), bv_volume: 38580
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E4b_Mut_reg.nii:, pos_len=280
#
# Number 105: img_size: (180, 242, 142), bv_size: (slice(31, 88, None), slice(97, 178, None), slice(57, 112, None)), bv_volume: 36795
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170619_En1_E12p5_Ex-files__upload/20170619_En1_E12_Ex_E2a_reg.nii:, pos_len=159
#
# Number 106: img_size: (180, 242, 202), bv_size: (slice(53, 97, None), slice(45, 119, None), slice(26, 108, None)), bv_volume: 35347
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170315_En1_E12p5-files__upload/20170315_En1_E12_E2b.nii:, pos_len=320
#
# Number 107: img_size: (180, 242, 202), bv_size: (slice(74, 133, None), slice(141, 208, None), slice(34, 124, None)), bv_volume: 28560
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170315_En1_E12p5-files__upload/20170315_En1_E12_E4a.nii:, pos_len=324
#
# Number 108: img_size: (180, 242, 202), bv_size: (slice(64, 107, None), slice(146, 213, None), slice(1, 118, None)), bv_volume: 37612
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170315_En1_E12p5-files__upload/20170315_En1_E12_E1a.nii:, pos_len=378
#
# Number 109: img_size: (180, 242, 202), bv_size: (slice(70, 147, None), slice(85, 166, None), slice(19, 76, None)), bv_volume: 23833
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E1a_filt.nii:, pos_len=216
#
# Number 110: img_size: (180, 242, 202), bv_size: (slice(52, 115, None), slice(125, 204, None), slice(84, 146, None)), bv_volume: 18862
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E3a_filt.nii:, pos_len=480
#
# Number 111: img_size: (180, 242, 222), bv_size: (slice(60, 113, None), slice(117, 187, None), slice(82, 153, None)), bv_volume: 17967
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E3b_filt.nii:, pos_len=294
#
# Number 112: img_size: (180, 242, 222), bv_size: (slice(80, 135, None), slice(119, 188, None), slice(95, 178, None)), bv_volume: 21736
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E2a_filt.nii:, pos_len=504
#
# Number 113: img_size: (180, 242, 202), bv_size: (slice(70, 147, None), slice(85, 165, None), slice(19, 74, None)), bv_volume: 21659
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E1b_filt.nii:, pos_len=216
#
# Number 114: img_size: (300, 242, 202), bv_size: (slice(81, 210, None), slice(151, 216, None), slice(108, 177, None)), bv_volume: 45584
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170301_En1_E12-files__upload/20170301_En1_E12_E2b_filt.nii:, pos_len=304
#
# Number 115: img_size: (180, 202, 202), bv_size: (slice(48, 95, None), slice(75, 168, None), slice(6, 84, None)), bv_volume: 34643
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170206_En1_E12p5-files__upload/20170206_En1_E12_E4a.nii:, pos_len=546
#
# Number 116: img_size: (180, 202, 128), bv_size: (slice(39, 93, None), slice(55, 139, None), slice(27, 112, None)), bv_volume: 35673
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170206_En1_E12p5-files__upload/20170206_En1_E12_E2a_Head.nii:, pos_len=191
#
# Number 117: img_size: (180, 202, 182), bv_size: (slice(56, 109, None), slice(104, 177, None), slice(43, 139, None)), bv_volume: 35377
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170206_En1_E12p5-files__upload/20170206_En1_E12_E3a.nii:, pos_len=224
#
# Number 118: img_size: (180, 202, 182), bv_size: (slice(55, 105, None), slice(33, 111, None), slice(40, 124, None)), bv_volume: 32016
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170206_En1_E12p5-files__upload/20170206_En1_E12_E1b.nii:, pos_len=336
#
# Number 119: img_size: (180, 202, 182), bv_size: (slice(39, 90, None), slice(58, 146, None), slice(85, 168, None)), bv_volume: 38150
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170206_En1_E12p5-files__upload/20170206_En1_E12_E2b.nii:, pos_len=168
#
# Number 120: img_size: (180, 222, 242), bv_size: (slice(43, 94, None), slice(50, 144, None), slice(65, 114, None)), bv_volume: 28284
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E1a_filt.nii:, pos_len=532
#
# Number 121: img_size: (180, 222, 202), bv_size: (slice(102, 157, None), slice(61, 152, None), slice(42, 134, None)), bv_volume: 39875
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E7a_filt.nii:, pos_len=224
#
# Number 122: img_size: (180, 222, 202), bv_size: (slice(68, 140, None), slice(89, 175, None), slice(40, 103, None)), bv_volume: 33254
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E8a_filt.nii:, pos_len=392
#
# Number 123: img_size: (180, 222, 202), bv_size: (slice(48, 120, None), slice(81, 146, None), slice(42, 97, None)), bv_volume: 24265
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E4a_filt.nii:, pos_len=616
#
# Number 124: img_size: (180, 222, 202), bv_size: (slice(44, 131, None), slice(70, 133, None), slice(11, 73, None)), bv_volume: 24128
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E3a_filt.nii:, pos_len=231
#
# Number 125: img_size: (180, 222, 162), bv_size: (slice(44, 115, None), slice(121, 178, None), slice(58, 141, None)), bv_volume: 25962
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E5a_filt.nii:, pos_len=245
#
# Number 126: img_size: (180, 222, 202), bv_size: (slice(72, 142, None), slice(118, 201, None), slice(7, 76, None)), bv_volume: 28914
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170705_En1_E12p5-files__upload/20170705_En1_E12_E6a_filt.nii:, pos_len=310
#
# Number 127: img_size: (180, 222, 242), bv_size: (slice(43, 105, None), slice(40, 133, None), slice(126, 213, None)), bv_volume: 37444
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E3a.nii:, pos_len=280
#
# Number 128: img_size: (180, 222, 202), bv_size: (slice(46, 108, None), slice(43, 141, None), slice(101, 176, None)), bv_volume: 37371
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E2a.nii:, pos_len=280
#
# Number 129: img_size: (180, 222, 202), bv_size: (slice(33, 105, None), slice(43, 115, None), slice(58, 152, None)), bv_volume: 33079
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E4a.nii:, pos_len=324
#
# Number 130: img_size: (180, 222, 202), bv_size: (slice(49, 93, None), slice(38, 139, None), slice(12, 74, None)), bv_volume: 25777
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E1a.nii:, pos_len=144
#
# Number 131: img_size: (180, 222, 202), bv_size: (slice(34, 79, None), slice(70, 147, None), slice(52, 143, None)), bv_volume: 25542
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E6a.nii:, pos_len=457
#
# Number 132: img_size: (180, 222, 202), bv_size: (slice(39, 105, None), slice(127, 188, None), slice(51, 141, None)), bv_volume: 27775
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E5b.nii:, pos_len=335
#
# Number 133: img_size: (180, 222, 202), bv_size: (slice(49, 97, None), slice(133, 199, None), slice(18, 109, None)), bv_volume: 22959
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E7a.nii:, pos_len=128
#
# Number 134: img_size: (180, 222, 202), bv_size: (slice(36, 103, None), slice(44, 127, None), slice(102, 180, None)), bv_volume: 32103
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20171002_En1_E12p5-files__upload/20171002_En1_E12_E8a.nii:, pos_len=213
#
# Number 135: img_size: (180, 202, 242), bv_size: (slice(32, 125, None), slice(96, 146, None), slice(31, 85, None)), bv_volume: 17484
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E7b_reg.nii:, pos_len=324
#
# Number 136: img_size: (180, 202, 242), bv_size: (slice(42, 127, None), slice(93, 155, None), slice(43, 98, None)), bv_volume: 16348
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E9a_reg.nii:, pos_len=448
#
# Number 137: img_size: (180, 202, 242), bv_size: (slice(54, 123, None), slice(71, 150, None), slice(34, 90, None)), bv_volume: 19546
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E12a_reg.nii:, pos_len=384
#
# Number 138: img_size: (180, 202, 240), bv_size: (slice(48, 99, None), slice(46, 146, None), slice(156, 221, None)), bv_volume: 19921
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E5a_reg.nii:, pos_len=192
#
# Number 139: img_size: (180, 202, 242), bv_size: (slice(57, 121, None), slice(62, 157, None), slice(33, 86, None)), bv_volume: 16439
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E11a_reg.nii:, pos_len=336
#
# Number 140: img_size: (180, 202, 242), bv_size: (slice(47, 135, None), slice(94, 157, None), slice(171, 228, None)), bv_volume: 17804
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E10a_reg.nii:, pos_len=168
#
# Number 141: img_size: (180, 222, 222), bv_size: (slice(44, 126, None), slice(100, 167, None), slice(22, 92, None)), bv_volume: 20161
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E2a_reg.nii:, pos_len=288
#
# Number 142: img_size: (180, 202, 242), bv_size: (slice(42, 127, None), slice(51, 118, None), slice(23, 90, None)), bv_volume: 19929
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E6a_reg.nii:, pos_len=252
#
# Number 143: img_size: (180, 202, 222), bv_size: (slice(48, 119, None), slice(30, 118, None), slice(123, 199, None)), bv_volume: 21411
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E3a_reg.nii:, pos_len=160
#
# Number 144: img_size: (180, 202, 242), bv_size: (slice(69, 121, None), slice(42, 135, None), slice(16, 86, None)), bv_volume: 16367
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E8a_reg.nii:, pos_len=168
#
# Number 145: img_size: (180, 202, 242), bv_size: (slice(62, 111, None), slice(50, 150, None), slice(157, 226, None)), bv_volume: 26101
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E4a_reg.nii:, pos_len=160
#
# Number 146: img_size: (180, 202, 242), bv_size: (slice(40, 130, None), slice(83, 142, None), slice(35, 89, None)), bv_volume: 18345
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170718_En1_E12p5-files__upload/20170718_En1_E12_E7a_reg.nii:, pos_len=426
#
# Number 147: img_size: (180, 242, 182), bv_size: (slice(38, 108, None), slice(22, 102, None), slice(48, 139, None)), bv_volume: 36862
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170321_En1_E12p5-files__upload/20170321_En1_E12_E6a.nii:, pos_len=230
#
# Number 148: img_size: (180, 242, 182), bv_size: (slice(54, 118, None), slice(142, 210, None), slice(26, 116, None)), bv_volume: 29997
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170321_En1_E12p5-files__upload/20170321_En1_E12_E5a.nii:, pos_len=200
#
# Number 149: img_size: (180, 242, 202), bv_size: (slice(32, 90, None), slice(129, 192, None), slice(38, 131, None)), bv_volume: 33558
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170321_En1_E12p5-files__upload/20170321_En1_E12_E4a.nii:, pos_len=336
#
# Number 150: img_size: (180, 242, 182), bv_size: (slice(63, 145, None), slice(61, 125, None), slice(112, 179, None)), bv_volume: 25777
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12/20170321_En1_E12p5-files__upload/20170321_En1_E12_E8a.nii:, pos_len=592
#
# ...
#
# Number 209: img_size: (180, 242, 222), bv_size: (slice(58, 130, None), slice(104, 192, None), slice(11, 69, None)), bv_volume: 23839
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20171004_En1_E13-files__upload/20171004_En1_E13_E1a.nii:, pos_len=184
#
# Number 210: img_size: (180, 242, 242), bv_size: (slice(62, 119, None), slice(85, 185, None), slice(153, 208, None)), bv_volume: 24419
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E3a_reg.nii:, pos_len=336
#
# Number 211: img_size: (180, 242, 222), bv_size: (slice(45, 148, None), slice(42, 92, None), slice(67, 123, None)), bv_volume: 18911
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E9a_Mut_reg.nii:, pos_len=462
#
# Number 212: img_size: (180, 242, 222), bv_size: (slice(33, 133, None), slice(113, 170, None), slice(137, 190, None)), bv_volume: 21196
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E7a_reg.nii:, pos_len=330
#
# Number 213: img_size: (180, 242, 202), bv_size: (slice(16, 91, None), slice(44, 96, None), slice(91, 163, None)), bv_volume: 17194
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E10a-Mut_reg.nii:, pos_len=165
#
# Number 214: img_size: (180, 242, 242), bv_size: (slice(47, 137, None), slice(102, 172, None), slice(23, 84, None)), bv_volume: 21624
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E11a_Mut_reg.nii:, pos_len=280
#
# Number 215: img_size: (180, 242, 242), bv_size: (slice(63, 156, None), slice(123, 172, None), slice(131, 205, None)), bv_volume: 16403
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E4a_reg.nii:, pos_len=264
#
# Number 216: img_size: (180, 242, 222), bv_size: (slice(26, 83, None), slice(79, 176, None), slice(96, 171, None)), bv_volume: 22656
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E5a_reg.nii:, pos_len=280
#
# Number 217: img_size: (180, 242, 222), bv_size: (slice(93, 160, None), slice(139, 194, None), slice(33, 119, None)), bv_volume: 15137
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E6a_reg.nii:, pos_len=186
#
# Number 218: img_size: (180, 222, 242), bv_size: (slice(59, 110, None), slice(68, 174, None), slice(49, 117, None)), bv_volume: 29623
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E1b_reg.nii:, pos_len=360
#
# Number 219: img_size: (180, 242, 182), bv_size: (slice(67, 118, None), slice(15, 69, None), slice(46, 149, None)), bv_volume: 25312
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E2b_reg.nii:, pos_len=144
#
# Number 220: img_size: (180, 242, 242), bv_size: (slice(47, 142, None), slice(112, 176, None), slice(18, 85, None)), bv_volume: 16890
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E12a_reg.nii:, pos_len=225
#
# Number 221: img_size: (180, 242, 222), bv_size: (slice(58, 152, None), slice(105, 170, None), slice(14, 70, None)), bv_volume: 18357
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170706_En1_E13p5-files__upload/20170706_En1_E13_E8a_reg.nii:, pos_len=165
#
# Number 222: img_size: (180, 282, 182), bv_size: (slice(31, 88, None), slice(125, 218, None), slice(3, 94, None)), bv_volume: 22308
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E7a.nii:, pos_len=339
#
# Number 223: img_size: (180, 282, 202), bv_size: (slice(45, 101, None), slice(120, 222, None), slice(121, 190, None)), bv_volume: 25365
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E3a.nii:, pos_len=144
#
# Number 224: img_size: (180, 282, 222), bv_size: (slice(64, 128, None), slice(87, 185, None), slice(3, 100, None)), bv_volume: 34538
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E2b.nii:, pos_len=112
#
# Number 225: img_size: (180, 282, 142), bv_size: (slice(42, 123, None), slice(98, 175, None), slice(22, 104, None)), bv_volume: 32227
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E4a.nii:, pos_len=189
#
# Number 226: img_size: (180, 282, 202), bv_size: (slice(60, 146, None), slice(163, 236, None), slice(121, 185, None)), bv_volume: 25453
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E6a.nii:, pos_len=126
#
# Number 227: img_size: (180, 282, 202), bv_size: (slice(44, 115, None), slice(43, 109, None), slice(63, 162, None)), bv_volume: 23888
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E13/20170322_En1_E13p5-files__upload/20170322_En1_E13_E5a.nii:, pos_len=329
#
# Number 228: img_size: (180, 242, 222), bv_size: (slice(71, 122, None), slice(71, 170, None), slice(22, 97, None)), bv_volume: 22091
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20170329_En1_E12p5-files__upload/20170329_En1_E12_E1a.nii:, pos_len=192
#
# Number 229: img_size: (180, 242, 222), bv_size: (slice(63, 137, None), slice(93, 174, None), slice(149, 216, None)), bv_volume: 31045
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20170329_En1_E12p5-files__upload/20170329_En1_E12_E7a.nii:, pos_len=168
#
# Number 230: img_size: (180, 242, 222), bv_size: (slice(52, 152, None), slice(88, 159, None), slice(146, 208, None)), bv_volume: 26806
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20170329_En1_E12p5-files__upload/20170329_En1_E12_E3a.nii:, pos_len=180
#
# Number 231: img_size: (180, 242, 222), bv_size: (slice(59, 131, None), slice(117, 197, None), slice(33, 103, None)), bv_volume: 27941
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20170329_En1_E12p5-files__upload/20170329_En1_E12_E5a.nii:, pos_len=336
#
# Number 232: img_size: (180, 242, 222), bv_size: (slice(43, 133, None), slice(122, 188, None), slice(38, 91, None)), bv_volume: 25757
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20170329_En1_E12p5-files__upload/20170329_En1_E12_E4a.nii:, pos_len=441
#
# Number 233: img_size: (180, 242, 242), bv_size: (slice(55, 113, None), slice(99, 203, None), slice(170, 227, None)), bv_volume: 22857
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E1b.nii:, pos_len=144
#
# Number 234: img_size: (180, 242, 202), bv_size: (slice(55, 121, None), slice(143, 210, None), slice(63, 170, None)), bv_volume: 33278
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E2a.nii:, pos_len=200
#
# Number 235: img_size: (210, 242, 222), bv_size: (slice(77, 137, None), slice(128, 219, None), slice(14, 83, None)), bv_volume: 27278
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E11a.nii:, pos_len=132
#
# Number 236: img_size: (210, 242, 162), bv_size: (slice(10, 82, None), slice(67, 171, None), slice(85, 142, None)), bv_volume: 24929
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E6a.nii:, pos_len=312
#
# Number 237: img_size: (180, 242, 202), bv_size: (slice(36, 98, None), slice(65, 137, None), slice(96, 178, None)), bv_volume: 22202
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E5a.nii:, pos_len=216
#
# Number 238: img_size: (210, 242, 202), bv_size: (slice(49, 106, None), slice(33, 125, None), slice(116, 182, None)), bv_volume: 21934
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E12a.nii:, pos_len=216
#
# Number 239: img_size: (180, 242, 222), bv_size: (slice(62, 127, None), slice(96, 191, None), slice(116, 199, None)), bv_volume: 23763
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E4a.nii:, pos_len=224
#
# Number 240: img_size: (210, 242, 202), bv_size: (slice(81, 155, None), slice(132, 213, None), slice(21, 110, None)), bv_volume: 26106
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E9a.nii:, pos_len=180
#
# Number 241: img_size: (210, 242, 202), bv_size: (slice(67, 133, None), slice(38, 125, None), slice(25, 90, None)), bv_volume: 19816
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E8a.nii:, pos_len=318
#
# Number 242: img_size: (210, 242, 222), bv_size: (slice(28, 123, None), slice(83, 153, None), slice(142, 211, None)), bv_volume: 18932
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E7a.nii:, pos_len=100
#
# Number 243: img_size: (210, 242, 202), bv_size: (slice(61, 111, None), slice(26, 101, None), slice(66, 161, None)), bv_volume: 24889
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12_Ext___tiff/20171009_En1_E12_E10a.nii:, pos_len=350
#
# Number 244: img_size: (180, 242, 222), bv_size: (slice(83, 135, None), slice(134, 201, None), slice(27, 123, None)), bv_volume: 25452
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12p5-files__upload/20171009_En1_E12_E2a.nii:, pos_len=245
#
# Number 245: img_size: (180, 242, 242), bv_size: (slice(72, 161, None), slice(104, 172, None), slice(19, 98, None)), bv_volume: 38028
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12p5-files__upload/20171009_En1_E12_E3a.nii:, pos_len=176
#
# Number 246: img_size: (180, 242, 262), bv_size: (slice(71, 136, None), slice(70, 152, None), slice(38, 127, None)), bv_volume: 37572
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12p5-files__upload/20171009_En1_E12_E5a.nii:, pos_len=392
#
# Number 247: img_size: (180, 242, 242), bv_size: (slice(36, 134, None), slice(35, 89, None), slice(12, 65, None)), bv_volume: 26801
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12p5-files__upload/20171009_En1_E12_E4a.nii:, pos_len=108
#
# Number 248: img_size: (180, 242, 182), bv_size: (slice(81, 141, None), slice(149, 214, None), slice(31, 140, None)), bv_volume: 21309
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171009_En1_E12p5-files__upload/20171009_En1_E12_E7a.nii:, pos_len=175
#
# Number 249: img_size: (180, 202, 182), bv_size: (slice(49, 134, None), slice(63, 132, None), slice(7, 63, None)), bv_volume: 37878
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E2a_reg.nii:, pos_len=160
#
# Number 250: img_size: (180, 202, 162), bv_size: (slice(72, 154, None), slice(50, 108, None), slice(15, 86, None)), bv_volume: 36669
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E4a_reg.nii:, pos_len=120
#
# Number 251: img_size: (180, 202, 162), bv_size: (slice(59, 134, None), slice(37, 81, None), slice(63, 119, None)), bv_volume: 31899
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E9a_reg.nii:, pos_len=245
#
# Number 252: img_size: (180, 202, 162), bv_size: (slice(62, 143, None), slice(84, 126, None), slice(21, 87, None)), bv_volume: 31884
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E10a_reg.nii:, pos_len=264
#
# Number 253: img_size: (180, 202, 162), bv_size: (slice(43, 132, None), slice(47, 117, None), slice(99, 153, None)), bv_volume: 35445
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E11a_reg.nii:, pos_len=112
#
# Number 254: img_size: (180, 202, 142), bv_size: (slice(42, 115, None), slice(117, 164, None), slice(33, 117, None)), bv_volume: 34628
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5_Ext-files__upload/20171122_En1_E12_Ext_E7a_reg.nii:, pos_len=126
#
# Number 255: img_size: (180, 202, 202), bv_size: (slice(69, 113, None), slice(76, 171, None), slice(11, 78, None)), bv_volume: 36520
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5-files__upload/20171122_En1_E12p5_E5a.nii:, pos_len=144
#
# Number 256: img_size: (180, 202, 202), bv_size: (slice(42, 103, None), slice(83, 166, None), slice(12, 79, None)), bv_volume: 32117
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5-files__upload/20171122_En1_E12p5_E2a.nii:, pos_len=126
#
# Number 257: img_size: (180, 202, 142), bv_size: (slice(64, 135, None), slice(22, 84, None), slice(48, 109, None)), bv_volume: 28226
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5-files__upload/20171122_En1_E12p5_E4a.nii:, pos_len=105
#
# Number 258: img_size: (180, 202, 202), bv_size: (slice(58, 115, None), slice(48, 126, None), slice(40, 118, None)), bv_volume: 38625
# Extracting positive: ...
# /scratch/zq415/grammar_cor/Localization/data/20180419_newdata_nii_with_filtered/E12.5/20171122_En1_E12p5-files__upload/20171122_En1_E12p5_E1b.nii:, pos_len=448
#
# 63608
